# %% [markdown]
# ## Imports and Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from IPython.utils import io
# for v in range(10):
#     print(v)
#     with io.capture_output() as captured:
#       installAdjust()

# %%
import tensorflow as tf
print(tf.__version__)
# !nvidia-smi
# Out:
# 2.5.0
# Mon Jan 10 22:58:14 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 496.76       Driver Version: 496.76       CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   46C    P8     5W /  N/A |    134MiB /  4096MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 68410, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 68410 (delta 3), reused 5 (delta 2), pack-reused 68403
# Receiving objects: 100% (68410/68410), 576.53 MiB | 13.88 MiB/s, done.
# Resolving deltas: 100% (48062/48062), done.

# %%
cd /content/models/research
# Out:
# /content/models/research

# %%
# %%capture
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# %%capture
# !git clone https://github.com/cocodataset/cocoapi.git

# %%
cd cocoapi/PythonAPI
# Out:
# /content/models/research/cocoapi/PythonAPI

# %%
# %%capture
# !make

# %%
cp -r pycocotools /content/models/research

# %%
cd ../../
# Out:
# /content/models/research

# %%
cp object_detection/packages/tf2/setup.py .

# %%
# %%capture
# !python -m pip install .

# %%
# %%capture
# !python object_detection/builders/model_builder_tf2_test.py

# %% [markdown]
# ## Evaluation Code

# %% [markdown]
# ### Faster RCNN Resnet 101 Evaluation

# %%
# cd /content/drive/MyDrive/BE Project/training
# cd C:\Programming\PythOn\Projects\CBIR\Implementation\Object Detection\self\training\

# %%
# /content/drive/MyDrive/BE Project/training/my_model/faster_rcnn_resnet101_v1_640x640

# %%
# run this if 
# ImportError: cannot import name '_registerMatType' from 'cv2.cv2' (/usr/local/lib/python3.7/dist-packages/cv2/cv2.cpython-37m-x86_64-linux-gnu.so)
# Such error is encountered

# !pip install "opencv-python-headless<4.3"
# Out:
# ...
#      |████████████████████████████████| 21.6 MB 1.5 MB/s
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.5.5.62
#     Uninstalling opencv-python-headless-4.5.5.62:
#       Successfully uninstalled opencv-python-headless-4.5.5.62
# ...

# %%
# Run this command in trainig folder in cmd or terminal in vscode
'''python model_main_tf2.py --model_dir=my_model/faster_rcnn_resnet101_v1_640x640 --pipeline_config_path=my_model/faster_rcnn_resnet101_v1_640x640/pipeline.config --checkpoint_dir=my_model/faster_rcnn_resnet101_v1_640x640 --alsologtostderr'''
# Out:
# 'python model_main_tf2.py --model_dir=my_model/faster_rcnn_resnet101_v1_640x640 --pipeline_config_path=my_model/faster_rcnn_resnet101_v1_640x640/pipeline.config --checkpoint_dir=my_model/faster_rcnn_resnet101_v1_640x640 --alsologtostderr'

# %%
# %load_ext tensorboard
# %reload_ext tensorboard
# %tensorboard --logdir training/my_model/faster_rcnn_resnet101_v1_640x640/
# taskkill /pid 13856 /f

# %load_ext tensorboard

# %tensorboard --logdir=training/my_model/faster_rcnn_resnet101_v1_640x640/ --host localhost --port 8888

# %%
# Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.521
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.436
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.738
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.741
# INFO:tensorflow:Eval metrics at step 5000
# I0110 13:48:36.197556 140424909244288 model_lib_v2.py:1015] Eval metrics at step 5000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.373654
# I0110 13:48:36.219645 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.373654
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.521177
# I0110 13:48:36.220992 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.521177
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.436406
# I0110 13:48:36.221874 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.436406
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): -1.000000
# I0110 13:48:36.222586 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.271105
# I0110 13:48:36.223304 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.271105
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.376701
# I0110 13:48:36.223985 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.376701
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.681443
# I0110 13:48:36.224668 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.681443
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.734925
# I0110 13:48:36.225355 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.734925
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.738267
# I0110 13:48:36.226029 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.738267
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0110 13:48:36.226674 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.402381
# I0110 13:48:36.227360 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.402381
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.741130
# I0110 13:48:36.228397 140424909244288 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.741130
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 0.188877
# I0110 13:48:36.229023 140424909244288 model_lib_v2.py:1018] 	+ Loss/RPNLoss/localization_loss: 0.188877
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.033619
# I0110 13:48:36.229651 140424909244288 model_lib_v2.py:1018] 	+ Loss/RPNLoss/objectness_loss: 0.033619
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.115843
# I0110 13:48:36.230332 140424909244288 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/localization_loss: 0.115843
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 0.203400
# I0110 13:48:36.231236 140424909244288 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/classification_loss: 0.203400
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I0110 13:48:36.232131 140424909244288 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 0.541738
# I0110 13:48:36.232761 140424909244288 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.541738

# %% [markdown]
# ### Centernet Resnet 50 Evaluation

# %%
'''conda activate tfod3'''
# Out:
# 'conda activate tfod3'

# %%
# Run this command in trainig folder in cmd or terminal in vscode
'''python model_main_tf2.py --model_dir=my_model/centernet_resnet50_v1_fpn_512x512 --pipeline_config_path=my_model/centernet_resnet50_v1_fpn_512x512/pipeline.config --checkpoint_dir=my_model/centernet_resnet50_v1_fpn_512x512 --alsologtostderr'''
# Out:
# 'python model_main_tf2.py --model_dir=my_model/centernet_resnet50_v1_fpn_512x512 --pipeline_config_path=my_model/centernet_resnet50_v1_fpn_512x512/pipeline.config --checkpoint_dir=my_model/centernet_resnet50_v1_fpn_512x512 --alsologtostderr'

# %%
# Go to model folder in 'mymodels' folder and run following commands in cmd
print('''conda activate tfod3
tensorboard --logdir=.''')
# Out:
# conda activate tfod3
# tensorboard --logdir=.

# %% [markdown]
#  <!-- Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.541
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.667
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.545
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.762
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.831
# INFO:tensorflow:Eval metrics at step 10000
# I0110 23:25:43.620398  5544 model_lib_v2.py:1006] Eval metrics at step 10000
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP: 0.541253
# I0110 23:25:43.687791  5544 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP: 0.541253
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP@.50IOU: 0.666667
# I0110 23:25:43.696740  5544 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP@.50IOU: 0.666667
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP@.75IOU: 0.625560
# I0110 23:25:43.704335  5544 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP@.75IOU: 0.625560
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP (small): -1.000000
# I0110 23:25:43.712221  5544 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP (medium): 0.361942
# I0110 23:25:43.721941  5544 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP (medium): 0.361942
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP (large): 0.544608
# I0110 23:25:43.730156  5544 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP (large): 0.544608
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@1: 0.762334
# I0110 23:25:43.736951  5544 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@1: 0.762334
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@10: 0.829144
# I0110 23:25:43.744331  5544 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@10: 0.829144
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@100: 0.829304
# I0110 23:25:43.752197  5544 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@100: 0.829304
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0110 23:25:43.758330  5544 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@100 (medium): 0.559524
# I0110 23:25:43.765029  5544 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@100 (medium): 0.559524
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@100 (large): 0.831103
# I0110 23:25:43.776534  5544 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@100 (large): 0.831103
# INFO:tensorflow:        + Loss/object_center: 1.326088
# I0110 23:25:43.783669  5544 model_lib_v2.py:1009]       + Loss/object_center: 1.326088
# INFO:tensorflow:        + Loss/box/scale: 0.414034
# I0110 23:25:43.789108  5544 model_lib_v2.py:1009]       + Loss/box/scale: 0.414034
# INFO:tensorflow:        + Loss/box/offset: 0.479472
# I0110 23:25:43.795070  5544 model_lib_v2.py:1009]       + Loss/box/offset: 0.479472
# INFO:tensorflow:        + Loss/total_loss: 2.219594
# I0110 23:25:43.800983  5544 model_lib_v2.py:1009]       + Loss/total_loss: 2.219594''' -->

# %% [markdown]
# ### Centernet Hourglass 104 Evaluation

# %%
'''conda activate tfod3'''
# Out:
# 'conda activate tfod3'

# %%
# Run this command in trainig folder in cmd or terminal in vscode
'''python model_main_tf2.py --model_dir=my_model/centernet_hg104_512x512 --pipeline_config_path=my_model/centernet_hg104_512x512/pipeline.config --checkpoint_dir=my_model/centernet_hg104_512x512 --alsologtostderr'''
# Out:
# 'python model_main_tf2.py --model_dir=my_model/centernet_hg104_512x512 --pipeline_config_path=my_model/centernet_hg104_512x512/pipeline.config --checkpoint_dir=my_model/centernet_hg104_512x512 --alsologtostderr'

# %%
# Go to model folder in 'mymodels' folder and run following commands in cmd
print('''conda activate tfod3
tensorboard --logdir=.''')
# Out:
# conda activate tfod3
# tensorboard --logdir=.

# %% [markdown]
# ### Efficientnet D1 Evaluation

# %%
'''conda activate tfod3'''
# Out:
# 'conda activate tfod3'

# %%
# Run this command in trainig folder in cmd or terminal in vscode
'''python model_main_tf2.py --model_dir=my_model/efficientdet_d1_coco17 --pipeline_config_path=my_model/efficientdet_d1_coco17/pipeline.config --checkpoint_dir=my_model/efficientdet_d1_coco17 --alsologtostderr'''
# Out:
# 'python model_main_tf2.py --model_dir=my_model/efficientdet_d1_coco17 --pipeline_config_path=my_model/efficientdet_d1_coco17/pipeline.config --checkpoint_dir=my_model/efficientdet_d1_coco17 --alsologtostderr'

# %%
# Go to model folder in 'mymodels' folder and run following commands in cmd
print('''conda activate tfod3
tensorboard --logdir=.''')
# Out:
# conda activate tfod3
# tensorboard --logdir=.

# %%
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.260
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.139
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.263
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.589
# INFO:tensorflow:Eval metrics at step 6000
# I0111 17:43:41.115158 25400 model_lib_v2.py:1006] Eval metrics at step 6000
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP: 0.141582
# I0111 17:43:41.127029 25400 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP: 0.141582
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP@.50IOU: 0.259525
# I0111 17:43:41.130445 25400 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP@.50IOU: 0.259525
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP@.75IOU: 0.138971
# I0111 17:43:41.134774 25400 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP@.75IOU: 0.138971
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP (small): -1.000000
# I0111 17:43:41.138731 25400 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP (medium): 0.263315
# I0111 17:43:41.142724 25400 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP (medium): 0.263315
# INFO:tensorflow:        + DetectionBoxes_Precision/mAP (large): 0.142301
# I0111 17:43:41.145714 25400 model_lib_v2.py:1009]       + DetectionBoxes_Precision/mAP (large): 0.142301
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@1: 0.511943
# I0111 17:43:41.150701 25400 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@1: 0.511943
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@10: 0.587257
# I0111 17:43:41.153693 25400 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@10: 0.587257
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@100: 0.588804
# I0111 17:43:41.158324 25400 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@100: 0.588804
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0111 17:43:41.160564 25400 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@100 (medium): 0.464286
# I0111 17:43:41.164554 25400 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@100 (medium): 0.464286
# INFO:tensorflow:        + DetectionBoxes_Recall/AR@100 (large): 0.588820
# I0111 17:43:41.168543 25400 model_lib_v2.py:1009]       + DetectionBoxes_Recall/AR@100 (large): 0.588820
# INFO:tensorflow:        + Loss/localization_loss: 0.007378
# I0111 17:43:41.171536 25400 model_lib_v2.py:1009]       + Loss/localization_loss: 0.007378
# INFO:tensorflow:        + Loss/classification_loss: 0.468174
# I0111 17:43:41.174802 25400 model_lib_v2.py:1009]       + Loss/classification_loss: 0.468174
# INFO:tensorflow:        + Loss/regularization_loss: 0.040812
# I0111 17:43:41.177797 25400 model_lib_v2.py:1009]       + Loss/regularization_loss: 0.040812
# INFO:tensorflow:        + Loss/total_loss: 0.516365
# I0111 17:43:41.180788 25400 model_lib_v2.py:1009]       + Loss/total_loss: 0.516365
